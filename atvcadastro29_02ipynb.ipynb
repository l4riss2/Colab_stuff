# %% [markdown]
# <a href="https://colab.research.google.com/github/l4riss2/Colab_stuff/blob/main/atvcadastro29_02ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
us_padrao="admin"
sn_padrao="admin"
us=str(input("Olá, por favor digite o seu nome de usuário:"))
s=str(input("Digite sua senha de login:"))

if us==us_padrao and s==sn_padrao:
  print("")
  print("Escolha alguma opção do menu:")
  print("1-Cadastro direto")
  print("2-Cadastro de professor")
  print("3-Cadastro de aluno")
  print("4-Calculadora")
  print("")
  op=int(input("Opção:"))

  if op==1:
    print("")
    us1=input("Digite seu nome de usuário:")
    sen1=input("Digite sua senha:")
    id1=int(input("Digite seu id:"))
    print("Seu cadastro foi realizado com sucesso.")
    print("Nome de usuário:",us1,"Senha:",sen1,"Id:",id1)

  elif op==2:
     print("")
     us2=input("Digite seu nome de usuario:")
     sen2=input("Digie sua senha:")
     id2=int(input("Digite seu id:"))
     mat1=input("Digite sua materia lecionada:")
     print("Seu cadastro foi realizado com sucesso.")
     print("Nome de usuário:",us2,"Senha:",sen2,"Id:",id2,"Matéria lecionada:",mat1)


  elif op==3:
     print("")
     us3=input("Digite seu nome de usuário:")
     sen3=(input("Digite sua senha:"))
     id3=int(input("Digite seu id:"))
     ano=input("Digite em qual serie escolar você está:")
     mat2=input("Digite sua materia:")
     print("Seu cadastro foi realizado com sucesso.")
     print("Nome de usuário:",us3,"Senha:",sen3,"Id:",id3,"Ano:",ano,"Matéria:",mat2)


  elif op==4:
      print("")
      print("Olá,escolha qual operação matemática você deseja realizar(+,-,*,/):")
      print("")
      print("Adição(+)")
      print("Subtração(-)")
      print("Multiplicação(*)")
      print("Divisão(/)")
      opr=input("Digite sua operação:")
      print("")
      num1=float(input("Dígite o seu primeiro número:"))
      num2=float(input("Dígite o seu segundo número:"))

      if opr=="+":
          r1=num1+num2
          print("Resultado:",r1)

      elif opr=="-":
          r2=num1-num2
          print("Resultado:",r2)

      elif  opr=="/":

          if num2!=0:
            r3=num1/num2
            print("Resultado:",r3)
          else:
            print("Erro:divisão por zero")

      elif opr=="*":
          r4=num1*num2
          print("Resultado:",r4)

      else:
        print("Não foi possivel realizar a operação")

elif us!=us_padrao and s==sn_padrao:
  print("Acesso negado,nome de usuario incorreto")

elif us==us_padrao and s!=sn_padrao:
  print("Acesso negado,senha incorreta")

else:
  print("Acesso negado, usuário e senha incorretos")
